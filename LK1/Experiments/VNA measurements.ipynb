# %%
# %matplotlib notebook

# %qtconsole

import logging
import time
from importlib import reload

from matplotlib import pyplot as plt
from matplotlib import colors, cm
import numpy as np

import qcodes as qc
from qcodes.dataset.experiment_container import new_experiment

# %%
from pytopo.qctools import instruments as instools
from pytopo.qctools.instruments import create_inst, add2station

from pytopo.sweep.base import Nest, Chain
from pytopo.sweep.decorators import getter, setter
from pytopo.sweep import sweep, do_experiment, hardsweep, measure

# %% [markdown]
# # Define measurement functions

# %%
def setup_frq_sweep(fstart, fstop, fpts, chan='S21', bw=None, navgs=None, pwr=None):
    """
    Setup a VNA trace.
    
    assumes that a channel with name chan is already created.
    """
    vna = qc.Station.default.vna
    trace = getattr(vna.channels, chan)
    
    fvals = np.linspace(fstart, fstop, fpts)
    trace.start(fstart)
    trace.stop(fstop)
    trace.npts(fpts)
    if navgs is not None:
        trace.avg(navgs)
    if bw is not None:
        trace.bandwidth(bw)
    if pwr is not None:
        trace.power(pwr)
    trace.autoscale()
    
    if not vna.rf_power():
        vna.rf_on()
    
    return fvals

def take_trace(chan='S21', plot=False):
    """
    Get the data of a currently measured trace.
    The trace has to be setup already.
    
    Returns magnitude (in dB) and phase (in rad).
    
    If plot is true, make a simple plot of the magnitude vs frequency.
    """
    vna = qc.Station.default.vna
    trace = getattr(vna.channels, chan)
    
    fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
    mag, phase = trace.trace_mag_phase()
    
    if plot:
        fig, ax = plt.subplots(1, 1)
        ax.plot(fvals*1e-9, 20*np.log10(mag))
        ax.grid(dashes=[1,1])
        ax.set_xlabel('Frequency (GHz)')
        ax.set_ylabel('Magnitude (dBm)')
        
    return mag, phase


@hardsweep(
    ind=[('frequency', 'Hz', 'array')], 
    dep=[('amplitude', '', 'array'), ('phase', 'rad', 'array')]
)
def vna_frequency_sweep(*arg, **kw):
    """
    Measurement function for a simple VNA trace for pytopo.sweep.
    
    All arguments will be passed to setup_trace.
    Return data is as returned by take_trace.
    """
    fvals = setup_frq_sweep(*arg, **kw)
    mag, phase = take_trace(plot=False)
    
    return fvals, np.vstack((mag, phase))


@hardsweep(
    ind=[('frequency', 'Hz', 'array')], 
    dep=[('magnitude', 'dB', 'array'), ('phase', 'rad', 'array')]
)
def vna_frequency_sweep_dB(*arg, **kw):
    """
    Measurement function for a simple VNA trace for pytopo.sweep.
    
    All arguments will be passed to setup_trace.
    Return data is as returned by take_trace.
    """
    fvals = setup_frq_sweep(*arg, **kw)
    mag, phase = take_trace(plot=False)
    
    return fvals, np.vstack((20*np.log10(mag), phase))


def setup_zerospan_trace(frq, npts, chan='S21', span=1.):
    """
    Setup the VNA to measure a trace around <frq> with <npts> samples
    in a very narray frequency span.
    """
    vna = qc.Station.default.vna
    trace = getattr(vna.channels, chan)
    
    trace.center(frq)
    trace.span(span)
    trace.npts(npts)
    
    trace.autoscale()
    
    if not vna.rf_power():
        vna.rf_on()


@hardsweep(
    ind=[('iteration', '', 'array')], 
    dep=[('amplitude', '', 'array'), ('phase', 'rad', 'array')]
)
def vna_timetrace(*arg, **kw):
    """
    Measure a 'time trace', emulated by a narrow span trace with many points.
    """
    setup_zerospan_trace(*arg, **kw)
    mag, phase = take_trace(plot=False)
    
    return np.arange(mag.size), np.vstack((mag, phase))


@hardsweep(
    ind=[('iteration', '', 'array')], 
    dep=[('magnitude', 'dB', 'array'), ('phase', 'rad', 'array')]
)
def vna_timetrace(*arg, **kw):
    """
    Measure a 'time trace', emulated by a narrow span trace with many points.
    """
    setup_zerospan_trace(*arg, **kw)
    mag, phase = take_trace(plot=False)
    
    return np.arange(mag.size), np.vstack((20*np.log10(mag), phase))

# %% [markdown]
# # Init station

# %% [markdown]
# ## Global variables

# %%
SAMPLE = "20170926_20nm_37_d2_CD20181017"

# %% [markdown]
# ## Init instruments

# %%
# %run -i "D:\OneDrive\Setups\LK1\LK1_code\Code\LK1\LK1\init_station.py"

# %%
from qcodes.instrument_drivers.rohde_schwarz.ZNB import ZNB
vna = create_inst(ZNB, 'vna', address='TCPIP::169.254.82.128::inst0::INSTR', force_new_instance=True)
station = qc.Station(vna)

# the VNA driver has some weird default settings. 
# Make sure here that we measure what we want
vna.clear_channels()
vna.add_channel('S21')
vna.rf_off()
# Out:
# Connected to: Rohde-Schwarz ZNB20-2Port (serial:1311601062101879, firmware:2.86) in 0.23s

# %%
#check that we can take the trace correctly
setup_frq_sweep(7.8e9, 8.5e9, 2001, bw=1e3, navgs=1, pwr=-40)
mag, phase = take_trace(plot=True)
# Out:
# <img src="data:image/png;base64,..." width="674.4444623111211">

# %%
from qcodes.instrument_drivers.rohde_schwarz.SGS100A import RohdeSchwarz_SGS100A
twpa_pump = create_inst(RohdeSchwarz_SGS100A, 'twpa_pump', address="TCPIP::169.254.2.20::inst0::INSTR")
# Out:
# Connected to: Rohde&Schwarz SGS100A (serial:1416.0505k02/110512, firmware:3.1.19.15-3.50.124.67) in 0.07s

# %% [markdown]
# # Testing

# %% [markdown]
# ## Quick manual trace (without saving)

# %%
setup_frq_sweep(fstart=3e9, fstop=10e9, fpts=1501, pwr=-50)
mag, phase = take_trace(plot=True)
# Out:
# <img src="data:image/png;base64,..." width="674.4444623111211">

# %% [markdown]
# # Take a single VNA trace

# %%
sweep_obj = vna_frequency_sweep_dB(fstart=5.29e9, fstop=5.33e9, fpts=4001, chan='S21')

result = do_experiment(f"VNA/{SAMPLE}", sweep_obj, live_plot=True)
# Out:
# Starting experimental run with id: 458

# %% [markdown]
# # Power dependence

# %%
sweep_obj = sweep(vna.S21.power, np.arange(-60., -9., 5.))(
    vna_frequency_sweep_dB(fstart=5.29e9, fstop=5.33e9, fpts=4001, chan='S21')
)

result = do_experiment(f"VNA_powersweep/{SAMPLE}", sweep_obj, live_plot=True)

# %% [markdown]
# # TWPA pump tune up

# %% [markdown]
# ## VNA as function of pump power

# %%
twpa_pump.on()
sweep_obj = sweep(twpa_pump.power, np.arange(12, 6, -1))(
    vna_frequency_sweep_dB(fstart=5.2e9, fstop=5.4e9, fpts=2001, chan='S21', navgs=1)
)

result = do_experiment(f"VNA_vs_pump_power/{SAMPLE}", sweep_obj, live_plot=True)
twpa_pump.off()
# Out:
# Starting experimental run with id: 323

# %% [markdown]
# ## VNA as function of pump frq

# %%
twpa_pump.power(9)
twpa_pump.on()
sweep_obj = sweep(twpa_pump.frequency, np.arange(7.92e9, 8.12e9, 1e6))(
    vna_frequency_sweep_dB(fstart=5.2e9, fstop=5.4e9, fpts=2001, chan='S21', navgs=1)
)

result = do_experiment(f"VNA_vs_pump_frequency/{SAMPLE}", sweep_obj, live_plot=True)
twpa_pump.off()

# %%
sweep_obj = sweep(twpa_pump.power, np.arange(9,5,-1))(
    sweep(twpa_pump.frequency, np.arange(7.96e9, 8.08e9, 1e6))(
    vna_frequency_sweep_dB(fstart=4e9, fstop=6e9, fpts=2001, chan='S21', navgs=1)
))

result = do_experiment(f"VNA_vs_pump_frequency/{SAMPLE}", sweep_obj, live_plot=True)
twpa_pump.off()

# %%
twpa_pump.power(5)

sweep_obj = sweep(twpa_pump.frequency, np.arange(7.96e9, 8.08e9, 1e6))(
    vna_frequency_sweep_dB(fstart=4e9, fstop=6e9, fpts=2001, chan='S21', navgs=1)
)

result = do_experiment(f"VNA_vs_pump_frequency/{SAMPLE}", sweep_obj, live_plot=True)

# %% [markdown]
# ## SNR as function of pump params

# %%
@getter(('signal', 'dB'), ('noise', 'dB'), ('SNR', 'dB'))
def get_SNR():
    time.sleep(0.01)
    mag, phase = take_trace(plot=False)
    sig = np.abs(mag) * np.exp(-1j*phase)
#     I, Q = sig.real, sig.imag
    lin_mean = np.abs(sig.mean())
    lin_std = np.abs(sig.std())
#     lin_mean = (I.mean()**2. + Q.mean()**2.)**.5
#     lin_std = (I.std()**2. + Q.std()**2.)**.5
    return 20*np.log10(lin_mean), 20*np.log10(lin_std), 20*np.log10(lin_mean/lin_std)

# %%
import time

# %%
time.sleep(7200)

# %%
twpa_pump.on()
vna.S21.avg(1)
vna.S21.power(-60)
setup_zerospan_trace(5.3045e9, 101)
      
sweep_obj = sweep(twpa_pump.power, np.arange(8.0, 12.0, .1))(
     sweep(twpa_pump.frequency, np.arange(7.8e9, 8.1e9, 0.5e6)))(
        measure(get_SNR)
)


result = do_experiment(f"TWPA_SNR/{SAMPLE}", sweep_obj, live_plot=True)
twpa_pump.off()
# Out:
# Starting experimental run with id: 878
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# Timeout during sending!
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# D:\OneDrive\Setups\LK1\LK1_code\Code\LK1\LK1\init_station.py in <module>()
#      10
#      11
# ---> 12 result = do_experiment(f"TWPA_SNR/{SAMPLE}", sweep_obj, live_plot=True)
#      13 twpa_pump.off()
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\do_experiment.py in do_experiment(experiment_name, sweep_object, setup, cleanup, station, live_plot)
#      92             )
#      93
# ---> 94         for data in sweep_object:
#      95             datasaver.add_result(*data.items())
#      96
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in __next__(self)
#      36             self._start_iter()
#      37
# ---> 38         return next(self._generator)
#      39
#      40     def __call__(self, *sweep_objects):
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in __next__(self)
#      36             self._start_iter()
#      37
# ---> 38         return next(self._generator)
#      39
#      40     def __call__(self, *sweep_objects):
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in _generator_factory(self)
#      79
#      80     def _generator_factory(self) ->Iterator:
# ---> 81         for value in self._iterator_function():
#      82             yield value
#      83
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in inner()
#     122         def inner():
#     123             for result2 in sweep_object2:
# --> 124                 for result1 in sweep_object1:
#     125                     result1.update(result2)
#     126                     yield result1
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in __next__(self)
#      36             self._start_iter()
#      37
# ---> 38         return next(self._generator)
#      39
#      40     def __call__(self, *sweep_objects):
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in _generator_factory(self)
#     152     def _generator_factory(self) ->Iterator:
#     153         for so in self._sweep_objects:
# --> 154             for result in so:
#     155                 yield result
#     156
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in __next__(self)
#      36             self._start_iter()
#      37
# ---> 38         return next(self._generator)
#      39
#      40     def __call__(self, *sweep_objects):
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\base.py in _generator_factory(self)
#     213
#     214     def _generator_factory(self)->Iterator:
# --> 215         yield self._get_function()
#     216
#     217
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\decorators.py in __call__(self, *args, **kwargs)
#      15
#      16     def __call__(self, *args, **kwargs):
# ---> 17         return self._caller(*args, **kwargs)
#      18
#      19     @property
#
# d:\onedrive\setups\lk1\lk1_code\code\pytopo\pytopo\sweep\decorators.py in inner()
#      91     def decorator(func: Callable) ->MeasureFunction:
#      92         def inner() ->dict:
# ---> 93             results = np.atleast_1d(func())
#      94             return {k[0]: v for k, v in zip(names_units, results)}
#      95
#
# D:\OneDrive\Setups\LK1\LK1_code\Code\LK1\LK1\init_station.py in get_SNR()
#       2 def get_SNR():
#       3     time.sleep(0.01)
# ----> 4     mag, phase = take_trace(plot=False)
#       5     sig = np.abs(mag) * np.exp(-1j*phase)
#       6 #     I, Q = sig.real, sig.imag
#
# D:\OneDrive\Setups\LK1\LK1_code\Code\LK1\LK1\init_station.py in take_trace(chan, plot)
#      37     trace = getattr(vna.channels, chan)
#      38
# ---> 39     fvals = np.linspace(trace.start(), trace.stop(), trace.npts())
#      40     mag, phase = trace.trace_mag_phase()
#      41
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\parameter.py in __call__(self, *args, **kwargs)
#     281         if len(args) == 0:
#     282             if hasattr(self, 'get'):
# --> 283                 return self.get()
#     284             else:
#     285                 raise NotImplementedError('no get cmd found in' +
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     404             except Exception as e:
#     405                 e.args = e.args + ('getting {}'.format(self),)
# --> 406                 raise e
#     407
#     408         return get_wrapper
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     360             try:
#     361                 # There might be cases where a .get also has args/kwargs
# --> 362                 value = get_function(*args, **kwargs)
#     363                 self.raw_value = value
#     364
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\utils\command.py in __call__(self, *args)
#     175             raise TypeError(
#     176                 'command takes exactly {} args'.format(self.arg_count))
# --> 177         return self.exec_function(*args)
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\utils\command.py in call_by_str(self, *args)
#     124     def call_by_str(self, *args):
#     125         """Execute a formatted string."""
# --> 126         return self.exec_str(self.cmd_str.format(*args))
#     127
#     128     def call_by_str_parsed_out(self, *args):
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\channel.py in ask(self, cmd)
#      66
#      67     def ask(self, cmd):
# ---> 68         return self._parent.ask(cmd)
#      69
#      70     def ask_raw(self, cmd):
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     744             inst = repr(self)
#     745             e.args = e.args + ('asking ' + repr(cmd) + ' to ' + inst,)
# --> 746             raise e
#     747
#     748     def ask_raw(self, cmd: str) -> str:
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\base.py in ask(self, cmd)
#     737         """
#     738         try:
# --> 739             answer = self.ask_raw(cmd)
#     740
#     741             return answer
#
# d:\onedrive\setups\lk1\lk1_code\code\qcodes\qcodes\instrument\visa.py in ask_raw(self, cmd)
#     227         """
#     228         self.visa_log.debug(f"Querying: {cmd}")
# --> 229         response = self.visa_handle.query(cmd)
#     230         self.visa_log.debug(f"Response: {response}")
#     231         return response
#
# C:\ProgramData\Anaconda3\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py in query(self, message, delay)
#     556         """
#     557
# --> 558         self.write(message)
#     559
#     560         delay = self.query_delay if delay is None else delay
#
# C:\ProgramData\Anaconda3\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py in write(self, message, termination, encoding)
#     221             message += term
#     222
# --> 223         count = self.write_raw(message.encode(enco))
#     224
#     225         return count
#
# C:\ProgramData\Anaconda3\envs\qcodes\lib\site-packages\pyvisa\resources\messagebased.py in write_raw(self, message)
#     199         :rtype: int
#     200         """
# --> 201         return self.visalib.write(self.session, message)
#     202
#     203     def write(self, message, termination=None, encoding=None):
#
# C:\ProgramData\Anaconda3\envs\qcodes\lib\site-packages\pyvisa\ctwrapper\functions.py in write(library, session, data)
#    1864     return_count = ViUInt32()
#    1865     # [ViSession, ViBuf, ViUInt32, ViPUInt32]
# -> 1866     ret = library.viWrite(session, data, len(data), byref(return_count))
#    1867     return return_count.value, ret
#    1868
#
# C:\ProgramData\Anaconda3\envs\qcodes\lib\site-packages\pyvisa\ctwrapper\highlevel.py in _return_handler(self, ret_value, func, arguments)
#     186
#     187         if ret_value < 0:
# --> 188             raise errors.VisaIOError(ret_value)
#     189
#     190         if ret_value in self.issue_warning_on:
#
# VisaIOError: ('VI_ERROR_INV_OBJECT (-1073807346): The given session or object reference is invalid.', "asking 'SENS1:FREQ:START?' to <ZNB: vna>", 'getting vna_S21_start')

# %%
twpa_pump.on()
vna.S21.avg(1)
vna.S21.power(-50)
setup_zerospan_trace(5.3136e9, 101)


sweep_obj = sweep(twpa_pump.frequency, np.arange(7.70e9, 7.94e9, 0.5e6))(
     sweep(twpa_pump.power, np.arange(-5.0, 14.0, .1)[::-1]))(
        measure(get_SNR)
)

result = do_experiment(f"TWPA_SNR/{SAMPLE}", sweep_obj, live_plot=True)

# %%
runid = 321
data = qc.dataset.data_export.load_by_id(runid)

# %%
SNR = np.array(data.get_data('SNR'))

# %%
SNR.max()
# Out:
# 40.495989290256198

# %%
twpa_pump.on()

# %%
twpa_pump.off()

# %%
twpa_pump.power(9)

# %%
twpa_pump.power()
# Out:
# 6.5

# %%
from matplotlib.colors import LogNorm

# %%
powers = np.arange(15,9,-1)
#for idnr, power in zip(ids,powers): 
data = qc.dataset.data_export.load_by_id(idnr)
freqs = data.get_data('frequency')
powers = data.get_data('twpa_pump_frequency')
signal = data.get_data('magnitude')


x = freqs[0][0]
y = np.array(powers)[:,0].T
X,Y = np.meshgrid(x,y)
Z = np.array(signal)[:,0,:]

#     # Znorm = Z
#     # for i in range(len(X[:,0])):
#     #     Znorm[i,:] = Z[i,:]/np.mean(Z[i,-15:-1])

#     plt.figure(figsize=(3, 3))
#     plt.pcolor(Y,X,Z,cmap='viridis', vmin=-60, vmax = 30)
#     plt.xlabel('TWPA Pump Frequency (GHz)')
#     plt.ylabel('VNA Frequency (GHz)')
#     plt.title('ID = %.i, TWPA Power = %.i'%(idnr,power))
#     cbar = plt.colorbar()
#     cbar.set_label('Magnitude (dB)')
#     plt.savefig("VNA_TWPA_%.i_%.i.png"%(idnr,power))
#     #plt.axis([x.min(),x.max(),y.min(), y.max()])
